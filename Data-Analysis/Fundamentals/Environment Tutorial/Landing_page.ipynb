# %% [markdown]
# **Landing page data analysis:**

# %% [markdown]
# Best you'll start with the [Basics](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Fundamentals).

# %% [markdown]
# Further steps are:
#
# [Preprocessing](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Preprocessing)
#
# [Sanity-Checks](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Sanity_Checks)
#
# [Visualization](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Visualization)

# %% [markdown]
# For more advanced analysis look at the [Analysis](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis) folder.
#
# There you can find tutorials for [TRF](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/TRF), [Coherence](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/Coherence), [Connectivity](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/Connectivity_Measures), [TMIF](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/TMIF), [Decoding](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/Deconding), [Time-Frequency-Analysis](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/Time_Frequency_Analysis) and [Sourcereconstruction](https://github.com/SalzburgBraindynamics/Wiki/tree/main/Data-Analysis/Analysis/Source_Reconstruction)
